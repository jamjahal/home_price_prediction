# %% [markdown]
# ## EDA  and Data Cleanng for Housing

# %%
import pandas as pd
import numpy as nd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplitlib inline
# Out:
# UsageError: Line magic function `%matplitlib` not found.

# %%
df = pd.read_csv('../datasets/train.csv')
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# ...

# %% [markdown]
# ### Missing values:
# - Lot Frontage
# - Alley
# - Mas Vnr Type
# - Mas Vnr Area
# - Bsmt Qual
# - Bsmt Cond
# - Bsmt Exposure
# - BsmtFin Type 1
# - BsmtFin SF 1
# - BsmtFin Type 2
# - BsmtFin SF 2
# - Bsmt Unf SF
# - Total Bsmt SF
# - Fireplace Qu
# - Garage Type
# - Garage Yr Blt
# - Garage Finish
# - Garage Cars
# - Garage Area
# - Garage Qual
# - Garage Cond
# - Pool QC
# - Fence
# - Misc Feature
#
# Not all properties will have all features, so missing data is acceptable.

# %%
df['Exter Qual']
# Out:
# 0       Gd
# 1       Gd
# 2       TA
# 3       TA
# 4       TA
#         ..
# 2046    Gd
# 2047    TA
# 2048    TA
# 2049    TA
# 2050    TA
# Name: Exter Qual, Length: 2051, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
# Id                 2051 non-null int64
# PID                2051 non-null int64
# MS SubClass        2051 non-null int64
# MS Zoning          2051 non-null object
# Lot Frontage       1721 non-null float64
# Lot Area           2051 non-null int64
# Street             2051 non-null object
# Alley              140 non-null object
# Lot Shape          2051 non-null object
# Land Contour       2051 non-null object
# Utilities          2051 non-null object
# Lot Config         2051 non-null object
# Land Slope         2051 non-null object
# Neighborhood       2051 non-null object
# Condition 1        2051 non-null object
# Condition 2        2051 non-null object
# Bldg Type          2051 non-null object
# House Style        2051 non-null object
# Overall Qual       2051 non-null int64
# Overall Cond       2051 non-null int64
# Year Built         2051 non-null int64
# ...

# %%
# Alley is object, check to verify 
df['Paved Drive'].sort_values()
# This looks correct
# Out:
# 1814    N
# 653     N
# 1952    N
# 738     N
# 410     N
#        ..
# 718     Y
# 716     Y
# 715     Y
# 748     Y
# 2050    Y
# Name: Paved Drive, Length: 2051, dtype: object

# %%
# Paved Drive looks like it could benefit from conversion to a bool

# %%
df.Fence.sort_values()
# Out:
# 958     GdPrv
# 948     GdPrv
# 292     GdPrv
# 285     GdPrv
# 278     GdPrv
#         ...
# 2046      NaN
# 2047      NaN
# 2048      NaN
# 2049      NaN
# 2050      NaN
# Name: Fence, Length: 2051, dtype: object

# %% [markdown]
# The Data types look to be appropriate for the most part.  Conversion of 'Paved Drive' column to a boolean type could prove useful.

# %%
# Determining how many observations are missing
null_col = [col for col in df.columns if df[col].isnull().any()]
df[null_col].isnull().sum()
# Out:
# Lot Frontage       330
# Alley             1911
# Mas Vnr Type        22
# Mas Vnr Area        22
# Bsmt Qual           55
# Bsmt Cond           55
# Bsmt Exposure       58
# BsmtFin Type 1      55
# BsmtFin SF 1         1
# BsmtFin Type 2      56
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1000
# Garage Type        113
# Garage Yr Blt      114
# Garage Finish      114
# Garage Cars          1
# Garage Area          1
# Garage Qual        114
# Garage Cond        114
# Pool QC           2042
# Fence             1651
# Misc Feature      1986
# dtype: int64

# %% [markdown]
# ## Cleaning Column Names
#
# I'm going to convert column names to snake case.

# %%
df.columns=df.columns.str.lower().str.replace(' ', '_').str.replace('qual', 'quality')

# %%
# Converting some column names to be more descriptive
new_columns_dict={
    'bsmtfin_sf_1' : 'bsmt_finished_sf_1',
    'bsmtfin_type_2': 'bsmt_finished_type_2',
    'bsmtfin_sf_2': 'bsmt_finished_sf_2',
    'gr_liv_area': 'gound_living_area',
    'mas_vnr_area' : 'masonry_veneer_area',
    'mas_vnr_type' : 'masonry_veneer_type'
    
}
df.rename(columns=new_columns_dict, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area',
#        'street', 'alley', 'lot_shape', 'land_contour', 'utilities',
#        'lot_config', 'land_slope', 'neighborhood', 'condition_1',
#        'condition_2', 'bldg_type', 'house_style', 'overall_quality',
#        'overall_cond', 'year_built', 'year_remod/add', 'roof_style',
#        'roof_matl', 'exterior_1st', 'exterior_2nd', 'masonry_veneer_type',
#        'masonry_veneer_area', 'exter_quality', 'exter_cond', 'foundation',
#        'bsmt_quality', 'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1',
#        'bsmt_finished_sf_1', 'bsmt_finished_type_2', 'bsmt_finished_sf_2',
#        'bsmt_unf_sf', 'total_bsmt_sf', 'heating', 'heating_qc', 'central_air',
#        'electrical', '1st_flr_sf', '2nd_flr_sf', 'low_quality_fin_sf',
#        'gound_living_area', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath',
#        'half_bath', 'bedroom_abvgr', 'kitchen_abvgr', 'kitchen_quality',
# ...

# %%
# Convert some columns to Categories
# df[['exter_quality', 
#     'exter_cond',
#     'bsmt_cond',
#     'bsmt_quality',
#     'heating_qc',
#     'kitchen_quality',
#     'fireplace_qu',
#     'garage_quality',
#     'garage_cond',
#     'pool_qc']].astype('category', categories=['NA','Po','Fa','TA','Gd','Ex'], 
#                                  ordered=True, inline=True)
# df.info()

# %%
df['exter_quality']=df['exter_quality'].astype('category')

df.exter_quality.dtype
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('exter_quality', 'exter_cond')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-1fe64b1c643a> in <module>
# ...

# %%
df['garage_quality'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Identify the Outliers

# %%
df.describe().T
# Out:
#                       count          mean           std          min  \
# id                   2051.0  1.474034e+03  8.439808e+02          1.0
# pid                  2051.0  7.135900e+08  1.886918e+08  526301100.0
# ms_subclass          2051.0  5.700878e+01  4.282422e+01         20.0
# lot_frontage         1721.0  6.905520e+01  2.326065e+01         21.0
# lot_area             2051.0  1.006521e+04  6.742489e+03       1300.0
# overall_qual         2051.0  6.112140e+00  1.426271e+00          1.0
# overall_cond         2051.0  5.562165e+00  1.104497e+00          1.0
# year_built           2051.0  1.971709e+03  3.017789e+01       1872.0
# year_remod/add       2051.0  1.984190e+03  2.103625e+01       1950.0
# masonry_veneer_area  2029.0  9.969591e+01  1.749631e+02          0.0
# bsmt_finished_sf_1   2050.0  4.423005e+02  4.612041e+02          0.0
# bsmt_finished_sf_2   2050.0  4.795902e+01  1.650009e+02          0.0
# bsmt_unf_sf          2050.0  5.677283e+02  4.449548e+02          0.0
# ...

# %% [markdown]
# - Max for garage_yr_built is 2207, far in the future.  I would like to see this garage, but in the meantime I will correct for what looks like a typo.
# - Max saleprice looks lower than I would expece, but perhaps I am jaded living in the Bay.

# %%
df['garage_yr_blt'].sort_values(ascending=False)
df.iloc[1699,:]
# Out:
# id                   2261
# pid             916384070
# ms_subclass            20
# ms_zoning              RL
# lot_frontage           68
#                   ...
# misc_val                0
# mo_sold                 9
# yr_sold              2007
# sale_type             New
# saleprice          267300
# Name: 1699, Length: 81, dtype: object

# %%
# Dropping the row with future garage built date
df.drop([1699],inplace=True)

# %%
df.iloc[1698:1700,:]
# Out:
#        id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1698  205  903430080           70        RM          52.0      3068   Pave
# 1700  423  528104070           60        RL         104.0     13518   Pave
#
#      alley lot_shape land_contour  ... screen_porch pool_area pool_qc  fence  \
# 1698  Grvl       Reg          Lvl  ...            0         0     NaN  GdPrv
# 1700   NaN       Reg          Lvl  ...            0         0     NaN    NaN
#
#      misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 1698          NaN        0       2    2010        WD      122000
# 1700          NaN        0       7    2009        New     485000
#
# [2 rows x 81 columns]

# %% [markdown]
# ## Exploratory visualizations

# %%
sns.pairplot(df, hue='labels')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'labels'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-acda3fe7e06e> in <module>
# ----> 1 sns.pairplot(df, hue='labels')
#
# ...
